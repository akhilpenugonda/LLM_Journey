# %% [markdown]
# ## Generating Code with Llama Code
#
# In this quick tutorial, you'll learn:
# - how to run Llama Code in free Colab
# - how to generate code with Llama Code
#
# *This Notebook is based on the official blog post from Hugging Face - [Code Llama: Llama 2 learns to code](https://huggingface.co/blog/codellama).*
#
# Other useful links:
# - [Code Llama Docs](https://huggingface.co/docs/transformers/main/model_doc/code_llama)
# - [Code Llama Model on HF](https://huggingface.co/codellama/CodeLlama-7b-hf)
#
# *Note: Ensure to run this notebook with enabled GPU. `Runtime` -> `Change Runtime Type` -> `T4`*
#
# Let's dive in!

# %% [markdown]
# ### Installing Hugging Face Dev

# %%
# !pip install git+https://github.com/huggingface/transformers.git@main accelerate
# Out:
# Collecting git+https://github.com/huggingface/transformers.git@main
#   Cloning https://github.com/huggingface/transformers.git (to revision main) to /private/var/folders/19/9w2nhv2n3dd54ppkjml8cts00000gn/T/pip-req-build-setxtxw4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /private/var/folders/19/9w2nhv2n3dd54ppkjml8cts00000gn/T/pip-req-build-setxtxw4
#   Resolved https://github.com/huggingface/transformers.git to commit ef42cb62744e2be04f5b41b7e36dd1d609734675
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (0.21.0)
# Requirement already satisfied: filelock in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (2.29.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.35.0.dev0)
#   Downloading tokenizers-0.14.1-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 12.4 MB/s eta 0:00:00a 0:00:01
# Collecting safetensors>=0.3.1 (from transformers==4.35.0.dev0)
#   Downloading safetensors-0.4.0-cp311-cp311-macosx_11_0_arm64.whl (425 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.4/425.4 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from transformers==4.35.0.dev0) (4.65.0)
# Requirement already satisfied: psutil in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: fsspec in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.0.dev0) (4.6.3)
# Requirement already satisfied: sympy in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->transformers==4.35.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->transformers==4.35.0.dev0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->transformers==4.35.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from requests->transformers==4.35.0.dev0) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/akhilkumarp/anaconda3/envs/NLP/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.35.0.dev0-py3-none-any.whl size=7791856 sha256=1a4dcfb2b20c0dc6ec3ed0817850baf67b1676c027ddf1ac4717f4afe3c4e24b
#   Stored in directory: /private/var/folders/19/9w2nhv2n3dd54ppkjml8cts00000gn/T/pip-ephem-wheel-cache-vmn9dsxg/wheels/bb/cb/6e/60d1799a10be9a6eeb01cb85fd51411adbfd9bc95d885ac15e
# Successfully built transformers
# Installing collected packages: safetensors, tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.17.0
#     Uninstalling transformers-4.17.0:
#       Successfully uninstalled transformers-4.17.0
# Successfully installed safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0.dev0

# %% [markdown]
# ### Loading the model and tokenizer

# %%
from transformers import AutoTokenizer
import transformers
import torch


model_id = "codellama/CodeLlama-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %% [markdown]
# ### Preparing the Pipeline

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:14<00:00,  7.48s/it]
# Loading checkpoint shards:   0%|          | 0/2 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> pipeline = transformers.pipeline(
#       <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     "text-generation",
#       <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     model=model_id,
#       <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     torch_dtype=torch.float16,
#       <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     device_map="auto",
#       <a href='vscode-notebook-cell:/Users/akhilkumarp/development/personal/github/LLM_Journey/Code_Llama_2_7B.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> )
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/transformers/pipelines/__init__.py:868, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     866 if isinstance(model, str) or framework is None:
#     867     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 868     framework, model = infer_framework_load_model(
#     869         model,
#     870         model_classes=model_classes,
#     871         config=config,
#     872         framework=framework,
#     873         task=task,
#     874         **hub_kwargs,
#     875         **model_kwargs,
#     876     )
#     878 model_config = model.config
#     879 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/transformers/pipelines/base.py:269, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     263     logger.warning(
#     264         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     265         "Trying to load the model with Tensorflow."
#     266     )
#     268 try:
# --> 269     model = model_class.from_pretrained(model, **kwargs)
#     270     if hasattr(model, "eval"):
#     271         model = model.eval()
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/transformers/modeling_utils.py:3333, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3323     if dtype_orig is not None:
#    3324         torch.set_default_dtype(dtype_orig)
#    3326     (
#    3327         model,
#    3328         missing_keys,
#    3329         unexpected_keys,
#    3330         mismatched_keys,
#    3331         offload_index,
#    3332         error_msgs,
# -> 3333     ) = cls._load_pretrained_model(
#    3334         model,
#    3335         state_dict,
#    3336         loaded_state_dict_keys,  # XXX: rename?
#    3337         resolved_archive_file,
#    3338         pretrained_model_name_or_path,
#    3339         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3340         sharded_metadata=sharded_metadata,
#    3341         _fast_init=_fast_init,
#    3342         low_cpu_mem_usage=low_cpu_mem_usage,
#    3343         device_map=device_map,
#    3344         offload_folder=offload_folder,
#    3345         offload_state_dict=offload_state_dict,
#    3346         dtype=torch_dtype,
#    3347         is_quantized=(getattr(model, "quantization_method", None) == QuantizationMethod.BITS_AND_BYTES),
#    3348         keep_in_fp32_modules=keep_in_fp32_modules,
#    3349     )
#    3351 model.is_loaded_in_4bit = load_in_4bit
#    3352 model.is_loaded_in_8bit = load_in_8bit
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/transformers/modeling_utils.py:3723, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, is_quantized, keep_in_fp32_modules)
#    3721 if low_cpu_mem_usage:
#    3722     if not is_fsdp_enabled() or is_fsdp_enabled_and_dist_rank_0():
# -> 3723         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    3724             model_to_load,
#    3725             state_dict,
#    3726             loaded_keys,
#    3727             start_prefix,
#    3728             expected_keys,
#    3729             device_map=device_map,
#    3730             offload_folder=offload_folder,
#    3731             offload_index=offload_index,
#    3732             state_dict_folder=state_dict_folder,
#    3733             state_dict_index=state_dict_index,
#    3734             dtype=dtype,
#    3735             is_quantized=is_quantized,
#    3736             is_safetensors=is_safetensors,
#    3737             keep_in_fp32_modules=keep_in_fp32_modules,
#    3738         )
#    3739         error_msgs += new_error_msgs
#    3740     else:
#
# File ~/anaconda3/envs/NLP/lib/python3.11/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, is_quantized, is_safetensors, keep_in_fp32_modules)
#     707             set_module_kwargs["dtype"] = torch.float32
#     708     else:
# --> 709         param = param.to(dtype)
#     711 # For compatibility with PyTorch load_state_dict which converts state dict dtype to existing dtype in model
#     712 if dtype is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Generating Code

# %%
def generate_code(prompt):
    sequences = pipeline(
        prompt,
        do_sample=True,
        temperature=0.1,
        top_p=0.9,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=128,
    )
    for seq in sequences:
        print(f"Result: {seq['generated_text']}")

# %% [markdown]
# ### Testing on Several Queries

# %%
generate_code("def fibonacci(")

# %%
generate_code("def factorial(")

# %%
generate_code("def remove_last_word(")

# %%
generate_code("def remove_non_ascii(s: str) -> str:")

# %% [markdown]
# ### Code Infilling
#
# For Future...

# %%
from transformers import pipeline
import torch

generator = pipeline("text-generation",model="codellama/CodeLlama-7b-hf",torch_dtype=torch.float16, device_map="auto")
# generator('def remove_non_ascii(s: str) -> str:\n    """ <FILL_ME>\n    return result', max_new_tokens = 128, return_type = 1)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model_id = "codellama/CodeLlama-7b-hf"
tokenizer2 = AutoTokenizer.from_pretrained(model_id)
model2 = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to("cuda")

# %%
prompt = '''def remove_non_ascii(s: str) -> str:
    """ <FILL_ME>
    return result
'''

input_ids = tokenizer(prompt, return_tensors="pt")["input_ids"].to("cuda")
output = model.generate(
    input_ids,
    max_new_tokens=200,
)
output = output[0].to("cpu")

filling = tokenizer.decode(output[input_ids.shape[1]:], skip_special_tokens=True)

# %%
print(prompt.replace("<FILL_ME>", filling))
